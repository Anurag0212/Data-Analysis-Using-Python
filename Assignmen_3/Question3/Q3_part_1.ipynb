# %% [markdown]
# # Question 3 Part One
# - Use ‘cricket_matches’ data set.
# - Calculate the average score for each team which host the game and win the game.
# - Remember that if a team hosts a game and wins the game, their score can be innings_1 runs or innings_2 runs. You have to check if the host team won the game, check which innings they played in (innings_1 or innings_2), and take the runs scored in that innings. The final answer is the average score of each team satisfying the above condition.
# - Display a few rows of the output use df.head()
# - Generate a csv output.

# %%
import pandas as pd
import numpy as np
from pandas import DataFrame as df

# %%
match_data=pd.read_csv(r'C:\Data Scienence\Assignmen_3\cricket_matches.csv')  #reading csv file and storing values in a Variable
match_data.head(3)
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
# 2  Midlands/Wales/West Group:Somerset v Warwicksh...
#
#                                              result  \
# 0  Durham won by 6 wickets (with 5 balls remaining)
# 1                           Hampshire won by 5 runs
# 2                       Warwickshire won by 19 runs
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# 2  Warwickshire 188/7 (20/20 ov); Somerset 169 (2...  13/06/2003
#
#                venue                      round       home             away  \
# 0  Chester-le-Street                North Group     Durham  Nottinghamshire
# 1        Southampton                South Group  Hampshire           Sussex
# 2            Taunton  Midlands/Wales/West Group   Somerset     Warwickshire
#
#          winner  win_by_runs   ...    innings1_wickets  innings1_overs_batted  \
# 0        Durham          NaN   ...                 7.0                   20.0
# 1     Hampshire          5.0   ...                10.0                   19.4
# 2  Warwickshire         19.0   ...                 7.0                   20.0
#
#   innings1_overs  innings2  innings2_runs  innings2_wickets  \
# 0           20.0    Durham          160.0               4.0
# 1           20.0    Sussex          148.0               7.0
# 2           20.0  Somerset          169.0              10.0
#
#    innings2_overs_batted innings2_overs  D/L_method  target
# 0                   19.1           20.0         NaN     NaN
# 1                   20.0           20.0         NaN     NaN
# 2                   20.0           20.0         NaN     NaN
#
# [3 rows x 24 columns]

# %%
filtered_data=match_data[match_data.home==match_data.winner]  #Applying filter to get the team names who hosts and wins the game
filtered_data.head(3)
# Out:
#                                        match_details  \
# 0  North Group:Durham v Nottinghamshire at Cheste...
# 1  South Group:Hampshire v Sussex at Southampton-...
# 3  South Group:Surrey v Middlesex at The Oval- Ju...
#
#                                              result  \
# 0  Durham won by 6 wickets (with 5 balls remaining)
# 1                           Hampshire won by 5 runs
# 3  Surrey won by 4 wickets (with 4 balls remaining)
#
#                                               scores        date  \
# 0  Nottinghamshire 157/7 (20/20 ov); Durham 160/4...  13/06/2003
# 1  Hampshire 153 (19.4/20 ov); Sussex 148/7 (20/2...  13/06/2003
# 3  Middlesex 155 (20/20 ov); Surrey 158/6 (19.2/2...  13/06/2003
#
#                venue        round       home             away     winner  \
# 0  Chester-le-Street  North Group     Durham  Nottinghamshire     Durham
# 1        Southampton  South Group  Hampshire           Sussex  Hampshire
# 3           The Oval  South Group     Surrey        Middlesex     Surrey
#
#    win_by_runs   ...    innings1_wickets  innings1_overs_batted  \
# 0          NaN   ...                 7.0                   20.0
# 1          5.0   ...                10.0                   19.4
# 3          NaN   ...                10.0                   20.0
#
#   innings1_overs  innings2  innings2_runs  innings2_wickets  \
# 0           20.0    Durham          160.0               4.0
# 1           20.0    Sussex          148.0               7.0
# 3           20.0    Surrey          158.0               6.0
#
#    innings2_overs_batted innings2_overs  D/L_method  target
# 0                   19.1           20.0         NaN     NaN
# 1                   20.0           20.0         NaN     NaN
# 3                   19.2           20.0         NaN     NaN
#
# [3 rows x 24 columns]

# %%
host_winning_match=pd.DataFrame(filtered_data.groupby('home').size().reset_index())  #Couting how many time a team hosts and wins the game
host_winning_match.columns=['Home','Number']                                         #Giving column names to the new data frame
host_winning_match.head(5)
# Out:
#                  Home  Number
# 0     Abahani Limited       1
# 1  Abbottabad Falcons      11
# 2   Abbottabad Region       3
# 3   Abbottabad Rhinos       2
# 4   Adelaide Strikers       9

# %%
winners_first_inning=filtered_data.groupby('home').apply(lambda x: x[x['winner']==x['innings1']]['innings1_runs'].sum())
winners_second_inning=filtered_data.groupby('home').apply(lambda x: x[x['winner']==x['innings2']]['innings2_runs'].sum())

# %%
Score=winners_first_inning+winners_second_inning
Score=pd.DataFrame(Score.reset_index())
Score.columns=['Home','Score']
Score.head(5)
# Out:
#                  Home   Score
# 0     Abahani Limited   172.0
# 1  Abbottabad Falcons  1534.0
# 2   Abbottabad Region   548.0
# 3   Abbottabad Rhinos   330.0
# 4   Adelaide Strikers  1468.0

# %%
average_score=pd.merge(host_winning_match,Score)
average_score['Average Score']=(average_score['Score']/average_score['Number'])
average_score.head(5)
# Out:
#                  Home  Number   Score  Average Score
# 0     Abahani Limited       1   172.0     172.000000
# 1  Abbottabad Falcons      11  1534.0     139.454545
# 2   Abbottabad Region       3   548.0     182.666667
# 3   Abbottabad Rhinos       2   330.0     165.000000
# 4   Adelaide Strikers       9  1468.0     163.111111

# %%
del average_score['Number']

# %%
average_score.head(5)
# Out:
#                  Home  Average Score
# 0     Abahani Limited     172.000000
# 1  Abbottabad Falcons     139.454545
# 2   Abbottabad Region     182.666667
# 3   Abbottabad Rhinos     165.000000
# 4   Adelaide Strikers     163.111111

# %%
average_score.to_csv(r'C:\Data Scienence\Assignmen_3\average_score.csv',index = False)
