# %% [markdown]
# # Question 8
# - Use nps_chat and wordlist corpus.
# - If you find a word in nps_chat but not in wordlist, it is considered an unusual word. (e.g. Heyyyy, gr8, 4ever can be  considered unusual words for this analysis)
# - Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# - Bonus: What if I want to  count : ) , : ( all these emoticons in. (optional)

# %%
import nltk
from nltk.corpus import nps_chat
from nltk.corpus import words

# %%
Wordlist_File=words.fileids()

words_list=[]
for WordfileId in Wordlist_File:
    for word in words.words(WordfileId):
        words_list.append(word.lower())
words_set=set(words_list)
print("There are",len(words_set),"total words in Word List\n")
# Out:
# There are 234377 total words in Word List

# %%
#Words from nps_chat excluding the ones containing User
Nps_Files=nps_chat.fileids()
word_list=[]
from xml.etree import ElementTree as ET
for id in Nps_Files:
    chat = nps_chat.raw(id)
    my_xml = ET.fromstring(chat)
    for child in my_xml.iter('t'):
        word_list.append(child.get('word'))
npschat_word_set=set()
for word in word_list:
    if 'User' not in word:
        npschat_word_set.add(word.lower());
print("There are",len(npschat_word_set),"total words excluding user names in Nps chat file\n")
# Out:
# There are 5274 total words excluding user names in Nps chat file

# %%
# words not present in words-list
final_word_set=set()
for nps_chat in npschat_word_set:
    if nps_chat not in words_set:
        final_word_set.add(nps_chat)
print("There are",len(final_word_set),"words which are not present in Word List\n\n")
print(final_word_set)
# Out:
# There are 2698 words which are not present in Word List
#
#
# {'', 'tackles', 'mmmmmmmmmmmmmm', 'welll', 'wz', '56.', 'antidepressants', '..........', 'chews', 'seuss', 'pullin', 'yall', 'rethinks', 'petunias', 'asking', 'compliments', 'howz', 'gawd', '3:45', 'j/p', 'nuff', 'poeple', '33982', 'yarrrr', '=p', '1200', 'heeeey', '&^', 'e-bay', '#talkcity_adults', 'birdgang', 'sigur', '*vbs*', 'whjat', '..', '38', 'arggghhh', 'nakie', 'akdt', 'hellos', 'massaged', '>.>->', '-17', 'lool', 'ohh', 'means', 'sharing', 'copone', 'hearin', 'hih', 'dumbass', '<33333', '29.88.', 'standin', 'ships', ':o', 'pandas', 'sumfin', 'oooh', 'biiiiiitch', 'misbehaving', 'runs', '2', '!!!!!!!!!!!!!!!!!!!!!!!!!!!', 'jeter', '~!', 'twoel', '.....', 'otay', 'mins', 'ooooook', 'spins', 'usa', 'issues', 'prittier', '25', 'rats', 'children', 'im', 'hahahaa', ')?', 'jammies', 'wings', 'in.', 'spain', ',,,', "iggy'd", 'yeee', 'bothering', 'stores', 'adds', 'rumours', 'aqwesome', 'wth', 'isnt', 'btw', '>:->', 'google', 'subsitute', 'plays', 'questioned', 're-thinking', 'adreniline', '!!!!!', '!!!!!!!!!!!!!!!!!!!!!!', 'bitches', "='s", 'ps2', 'brbbb', 'tthe', 'akst', 'othah', 'hooooo', 'pedals', 'awesomes', 'bro', 'dreams', 'aok', 'dvd', 'problems', 'ooopppps', 'mom', '9:10', 'eggs', 'kmph', '5', '818', "'d", 'e-husband', 'sox', 'whaaa', 'wher', 'lmaoooo', '(', 'ello', 'depeche', 'hiii', 'sum1', 'cutes', 'lesbo', 'sweats', 'images', 'okey', 'aloha', 'cuz', '((((((((((((((((((', 'othing', 'ooh', 'shaneeeeeeeee', 'byeeeeeeeeeeeee', 'thang', 'dayum', 'iamahotnip', 'affari', 'stories', 'ltns', 'doody', 'iamahotnipwithhotnippics', 'kong', 'tastes', 'bikes', 'whaaaaats', "'m", 'scares', 'smewchies', 'haters', 'finers', 'x-mas', 'hii', 'hehehehe', '!!!!!!', 'elev', 'iz', 'hgey', 'yeas', 'hahaaa', '.........', 'dated', 'appologize', 'shouldve', 'amazingness', 'lovin', 'psh', 'beattles', 'afk', 'loved', 'delivers', 'declawed', 'contemplating', 'flashed', 'rained', 'abortions', '!!!!!!!!', 'yawns', 'hugsss', 'lousiana', ';-(', ';p', '80', 'lurks', 'newp', 'donno', 'coughs', 'liked', 'impared', 'beuty', 'tooooooooooo', '\\', 'has', 'sighs', 'numbers', 'adoted', 'hiyas', 'k-fed', 'veg', 'clicked', 'shrugs', 'dolls', 'files', 'shakin', 'greetings', 'ballin', 'wel', 'wigglez', '!...', 'peppersteak', 'dokken', 'awww', '1.98', 'tounge', 'tennessee', 'remembers', 'pulling', 'callifornia', 'thinks', 'sentences', 'brwn', 'clooney', 'ssid', 'hes', 'toes', 'hugss', 'hugsssssssss', 'changing', 'dawnstar', 'showered', 'outta', 'topics', 'fuked', 'pmsl', 'nad', 'peeks', 'confessed', 'sicily', 'ahhh', '28', 'parents', '92780', '@$$', 'polllution', 'twizted', '31', 'moved', 'constituents', '75', 'lpn', 'rashes', 'picks', 'roomate', 'downnnnnn', '99703', '@', 'fwd', 'n"t', 'smiles', '))))))))))', 'disocvered', '+*+*+*+*', 'lthen', 'reunion.', 'comments', ':/', 'cries', 'brrrrrrr', 'http://www.shadowbots.com', 'aaahhhh', '<333333333', 'warnings', 'knees', '57401', 'buses', 'wheres', '1980', 'proud', 'awwwwwwwwww', 'diggin', 'wooo', 'normy', 'asks', 'burpin', 'laters', '...', '6', 'blech', 'hubbys', 'hawt', 'pictures', 'suffers', 'meyooky', 'owuldnt', '246', '*sniffs*', 'feeds', 'lucy-fur', 'decades', 'belongings', 'oates', 'sumpin', 'shit', "rn's", '.. .', 'aol.com', 'plows', 'concernin', 'chatr', 'tazzmaniane', 'heheh', '!!!!!!!!!!!!!!!!!!!!!!!', '4', 'freaks', '2:55', 'urself', 'cyber', 'lookin', 'kiddin', 'fucker', '33', 'harley', ';0', '55%', 'downloading', "s'", '16.', 'churches', '8', 'ignoring', '^_^', 'livin', 'yikes', '-stay-', 'kidding', 'ms', 'heyyyyyyyyyy', 'fongul', 'jayse', 'chocha', 'caps', 'temples', '??????', 'mami', 'totaly', 'pervin', '*hugs*', 'onuimso', 'vetrabrate', '14', '55', '((((((((((((((((((((((((((', '05.', 'makes', 'foxwoods', 'waddles', 'hangs', 'horrified', 'vbox', '!=', 'worl', '8082653953', '$$', 'items', 'warned', 'eeww', '.)', 'ohhhhhhhhhhhhhhhh', 'houses', 'hgfhgfjgf', 'hr', '(((((((((((', '=d', 'internet', '>_>', 'skateboard', '90', 'hx', 'cakes', 'insuklting', 'bigest', 'owww', '( o y o )', '_', 'sw', 'lubbs' ...
